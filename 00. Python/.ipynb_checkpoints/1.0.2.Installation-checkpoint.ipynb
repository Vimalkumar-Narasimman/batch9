# %% [markdown]
# ## Installation
#
#  ![image-2.png](attachment:image-2.png)
#
# https://www.python.org/downloads/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Installation on Mac OS X: For Mac OS X users, use  Homebrew
#
# Installation on GNU/Linux: For GNU/Linux users, use your distribution's package manager to install Python 3, e.g. on Debian & Ubuntu: sudo apt-get update && sudo apt-get install python3
#
# * https://www.debian.org/doc/manuals/maint-guide/first.en.html for Debian users
# * https://en.opensuse.org/Portal:Packaging for OpenSuse users
# * https://docs-old.fedoraproject.org/en-US/Fedora_Draft_Documentation/0.1/html/RPM_Guide/ch-creating-rpms.html for Fedora users
# http://www.slackbook.org/html/package-management-making-packages.html for Slackware users

# %% [markdown]
# ### Python IDEs
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Using Jupyter Notebook
#
# ![image-2.png](attachment:image-2.png)
