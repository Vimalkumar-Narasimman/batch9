# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
import sklearn

# %% [markdown]
# Importing and reading the file

# %%
data = pd.read_csv('Data/diamonds.csv', index_col=0)
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Diamonds Dataset
# Source : https://www.kaggle.com/shivam2503/diamonds
# price price in US dollars ($326--$18,823)
#
# carat weight of the diamond (0.2--5.01)
#
# cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# color diamond colour, from J (worst) to D (best)
#
# clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# x length in mm (0--10.74)
#
# y width in mm (0--58.9)
#
# z depth in mm (0--31.8)
#
# depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# table width of top of diamond relative to widest point (43--95)

# %%
data.reset_index(inplace=True, drop=True)
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Shape of the data

# %%
data.shape
# Out:
# (53940, 10)

# %% [markdown]
# Checking for NULL values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# Describing the data in terms of Bivariate Measures specifically correlation and heatmap

# %%
correlation = data.corr(numeric_only = True)

correlation
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
plt.subplots(figsize=(10, 8))
sns.heatmap(correlation, annot=True)
plt.show()

# %% [markdown]
# Finding all unique values for all categorical attributes

# %%
data['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
data['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
data['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
data['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %% [markdown]
# Charting out the box plot for bivariate and graphical summaries between the categorical value and price

# %%
data.boxplot(by = 'cut', column=['price'], grid = False, figsize=(10, 8))
# Out:
# <Axes: title={'center': 'price'}, xlabel='cut'>

# %%
data.boxplot(by = 'color', column = ['price'], grid = False, figsize=(10, 8))
# Out:
# <Axes: title={'center': 'price'}, xlabel='color'>

# %%
data.boxplot(by = 'clarity', column = ['price'], grid = False, figsize=(10, 8) )
# Out:
# <Axes: title={'center': 'price'}, xlabel='clarity'>

# %% [markdown]
# Scatter plot to graph the numeric features vs price

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(data['carat'], data['price'])

plt.xlabel('carat')
plt.ylabel('price')
plt.show()

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(data['x'], data['price'])
plt.xlabel('x')
plt.ylabel('price')
plt.show()

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(data['x'], data['price'])
plt.xlabel('x')
plt.ylabel('price')
plt.show()

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(data['y'], data['price'])
plt.xlabel('y')
plt.ylabel('price')
plt.show()

# %%
plt.subplots(figsize=(10, 8))

plt.scatter(data['z'], data['price'])

plt.xlabel("z")
plt.ylabel("price")

plt.show()

# %% [markdown]
# Converting the the Categorical value into numerical one with higher ranking and low ranking

# %%
clarity_dict = {"IF" : 7, "VVS1": 6, "VVS2" : 5, "VS1" : 4, "VS2" : 3, "SI1" : 2, "SI2" : 1, "I1" : 0}

data['clarity'].replace(clarity_dict, inplace=True)

data.head()
# Out:
# C:\Users\Vimalkumar\AppData\Local\Temp\ipykernel_23636\78456533.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['clarity'].replace(clarity_dict, inplace=True)
# C:\Users\Vimalkumar\AppData\Local\Temp\ipykernel_23636\78456533.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['clarity'].replace(clarity_dict, inplace=True)
#    carat      cut color  clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E        1   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I        3   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J        1   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# The rest can be converted to 0 and 1 since there is no value/order to it. We would use label encoder ideally, but since it is multiple attributes to encode we use dummies

# %%
data = pd.get_dummies(data, columns =['cut', 'color'])
data.head()
# Out:
#    carat  clarity  depth  table  price     x     y     z  cut_Fair  cut_Good  \
# 0   0.23        1   61.5   55.0    326  3.95  3.98  2.43     False     False
# 1   0.21        2   59.8   61.0    326  3.89  3.84  2.31     False     False
# 2   0.23        4   56.9   65.0    327  4.05  4.07  2.31     False      True
# 3   0.29        3   62.4   58.0    334  4.20  4.23  2.63     False     False
# 4   0.31        1   63.3   58.0    335  4.34  4.35  2.75     False      True
#
#    cut_Ideal  cut_Premium  cut_Very Good  color_D  color_E  color_F  color_G  \
# 0       True        False          False    False     True    False    False
# 1      False         True          False    False     True    False    False
# 2      False        False          False    False     True    False    False
# 3      False         True          False    False    False    False    False
# 4      False        False          False    False    False    False    False
#
#    color_H  color_I  color_J
# 0    False    False    False
# 1    False    False    False
# 2    False    False    False
# 3    False     True    False
# 4    False    False     True

# %% [markdown]
# Univariate summmary of the numerical features and we will need to scale the data

# %%
numeric_features = ['carat', 'table', 'depth', 'x', 'y', 'z']

numeric_df = data[numeric_features]
numeric_df.describe()
# Out:
#               carat         table         depth             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     57.457184     61.749405      5.731157      5.734526
# std        0.474011      2.234491      1.432621      1.121761      1.142135
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     56.000000     61.000000      4.710000      4.720000
# 50%        0.700000     57.000000     61.800000      5.700000      5.710000
# 75%        1.040000     59.000000     62.500000      6.540000      6.540000
# max        5.010000     95.000000     79.000000     10.740000     58.900000
#
#                   z
# count  53940.000000
# mean       3.538734
# std        0.705699
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %% [markdown]
# Importing the proper sci-kit learn libraries to perform scaling, training, testing and evaluation of data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# Creating a function for Linear Regression Model fit on the data

# %%
from sklearn.linear_model import LinearRegression

def linear_model(x_train, y_train):
    print("Linear Regression: ")
    linear_regression = LinearRegression()
    linear_regression.fit(x_train, y_train)
    return linear_regression

# %% [markdown]
# Creating a function for Lasso Regression Model fit on the data

# %%
from sklearn.linear_model import Lasso

def lasso_model(x_train, y_train):
    print("Lasso Regression : ")
    lasso_regression = Lasso(alpha=0.8, max_iter=10000)
    lasso_regression.fit(x_train, y_train)
    return lasso_regression

# %% [markdown]
# Creating a function for Ridge Regression Model fit on the data

# %%
from sklearn.linear_model import Ridge

def ridge_model(x_train, y_train):
    print("Ridge Regression : ")
    ridge_regression = Ridge(alpha=0.9)
    ridge_regression.fit(x_train, y_train)
    return ridge_regression

# %% [markdown]
# Creating a function for Sochastic Gradient Descent Regression Model fit on the data

# %%
from sklearn.linear_model import SGDRegressor

def sgd_model(x_train, y_train):
    print("SGD Regression : ")
    sgd_regression = SGDRegressor(max_iter=2000)
    sgd_regression.fit(x_train, y_train)
    return sgd_regression

# %% [markdown]
# Creating a function for MLP Regressor Neural Network to fit the data. 3 Hidden layers, with 12 neurons each.

# %%
from sklearn.neural_network import MLPRegressor

def mlp_model(x_train, y_train):
    mlp_regression = MLPRegressor(activation='relu', hidden_layer_sizes={12, 12, 12}, solver='lbfgs', verbose = True, max_iter= 20000)
    mlp_regression.fit(x_train, y_train)
    return mlp_regression

# %% [markdown]
# Creating a Function for building, training and evaluating the model by using the train test split method where X is all variables but the median value and Y is target name = price. The function preprocesses the data using standard scaler, trains the model ans print out the r2 score for accuracy, with the predicted values vs actual values.

# %%
def build_and_train_model(data, target_name, reg_fn):
    X = data.drop(target_name, axis=1)

    Y = data[target_name]
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state =0)

    scaler = StandardScaler()
    scaler.fit(x_train)
    x_train = scaler.transform(x_train)

    x_test = scaler.transform(x_test)

    model = reg_fn(x_train, y_train)
    score = model.score(x_train, y_train)
    print("Training Score : ", score)

    y_pred = model.predict(x_test)
    r_score = r2_score(y_test, y_pred)
    print("Testing Score : ", r_score)

    df_y = pd.DataFrame({'y_pred' : y_pred,'y_test' : y_test})
    print(df_y.sample(10))
  

    return {'model' : model, 
            'x_train' : x_train, 'x_test' : x_test,
            'y_train' : y_train, 'y_test' : y_test, 
            'y_pred' : y_pred
           }

# %% [markdown]
# Utilizing the build and train model function to predict and score the lasso model on the data. 3 inputs as needed: data file, value to predict(price), and the type of model below. Results in order Training score, Testing/r2 score to predict accuracy, and the Y_test: actual values and Y_pred = predicted values.

# %%
linear_regression = build_and_train_model(data, 'price', linear_model)
# Out:
# Linear Regression:
# Training Score :  0.9099020076877603
# Testing Score :  0.9126195831463633
#              y_pred  y_test
# 45216   1874.060873    1656
# 6721     548.560873     577
# 38958   -772.439127     489
# 28159    946.060873     665
# 20257   8061.060873    8687
# 21928  10375.748373   10002
# 52435   3576.060873    2513
# 4102    4668.810873    3536
# 6237    4517.810873    4007
# 865     3523.060873    2872

# %%
lasso_regression = build_and_train_model(data, 'price', lasso_model)
# Out:
# Lasso Regression :
# Training Score :  0.9099008418586947
# Testing Score :  0.9125701890225874
#              y_pred  y_test
# 44753   1518.537340    1619
# 48413   2555.690794    1970
# 45496   2159.038443    1680
# 38862   1265.222647    1050
# 25398  11325.595190   14105
# 6732     345.247790     577
# 1872    4269.698479    3072
# 12736   5721.969121    5315
# 39043   1887.071619    1056
# 46045    677.907543    1730

# %%
ridge_regression = build_and_train_model(data, 'price', ridge_model)
# Out:
# Ridge Regression :
# Training Score :  0.9099057339042314
# Testing Score :  0.9126091873660963
#             y_pred  y_test
# 2620   4059.592402    3226
# 43064  3015.904848    1377
# 19923  9284.327632    8470
# 22013  9423.036657   10080
# 24264  9867.521120   12490
# 42272   735.593394     505
# 30089    61.041738     720
# 12605  5379.397376    5288
# 30462    28.436644     732
# 42812  1444.952560    1353

# %%
sgd_regression = build_and_train_model(data, 'price', sgd_model)
# Out:
# SGD Regression :
# Training Score :  0.9095410726159392
# Testing Score :  0.9124456070970863
#             y_pred  y_test
# 49250  2084.343339    2086
# 10908  4540.115210    4887
# 22132  9953.120312   10164
# 1964   2844.943472    3089
# 31145   568.501030     755
# 18980  8754.668275    7812
# 45618  2101.239720    1692
# 16753  6731.625192    6670
# 16171  6997.722967    6464
# 16034  -640.023242     608

# %%
mlp_regression = build_and_train_model(data, 'price', mlp_model)
# Out:
# Training Score :  0.9643390479981585
# Testing Score :  0.960987262856912
#             y_pred  y_test
# 44942  1678.327846    1634
# 9026   4319.521539    4516
# 10642  4460.201133    4834
# 2702    587.915799     562
# 4293   3754.567668    3588
# 39613   399.833548     491
# 36292   492.178017     477
# 786    2391.664139    2861
# 41837  1477.359493    1253
# 31606   271.124328     368
