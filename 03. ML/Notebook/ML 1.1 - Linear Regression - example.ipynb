# %% [markdown]
# Linear regression finds the best possible linear equation that fits to the training data.

# %%
# !pip install quandl
# Out:
# Collecting quandl
#   Obtaining dependency information for quandl from https://files.pythonhosted.org/packages/c9/cd/54ab3484243431e02dabab1254ffde296c005e0d11346536e5e02ce6c828/Quandl-3.7.0-py2.py3-none-any.whl.metadata
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pandas>=0.14 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from quandl) (2.2.0)
# Requirement already satisfied: numpy>=1.8 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from quandl) (1.26.3)
# Requirement already satisfied: requests>=2.7.0 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from quandl) (2.31.0)
# Collecting inflection>=0.3.1 (from quandl)
#   Obtaining dependency information for inflection>=0.3.1 from https://files.pythonhosted.org/packages/59/91/aa6bde563e0085a02a435aa99b49ef75b0a4b062635e606dab23ce18d720/inflection-0.5.1-py2.py3-none-any.whl.metadata
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from quandl) (2.8.2)
# Requirement already satisfied: six in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from quandl) (1.16.0)
# Collecting more-itertools (from quandl)
#   Obtaining dependency information for more-itertools from https://files.pythonhosted.org/packages/50/e2/8e10e465ee3987bb7c9ab69efb91d867d93959095f4807db102d07995d94/more_itertools-10.2.0-py3-none-any.whl.metadata
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.14->quandl) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.14->quandl) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.7.0->quandl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.7.0->quandl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.7.0->quandl) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vimalkumar\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.7.0->quandl) (2023.11.17)
# Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------- ----------- 41.0/57.0 kB 960.0 kB/s eta 0:00:01
#    ---------------------------------------- 57.0/57.0 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: more-itertools, inflection, quandl
# Successfully installed inflection-0.5.1 more-itertools-10.2.0 quandl-3.7.0
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import quandl, math
from sklearn import preprocessing, svm, model_selection
from sklearn.linear_model import LinearRegression 
import matplotlib.pyplot as plt
from matplotlib import style
import pickle

# getting data
if not os.path.isfile(os.path.abspath("data/wiki_googl.csv")):
    df = quandl.get("WIKI/GOOGL")
else:
    df = pd.read_csv("data/wiki_googl.csv")

# use date as index
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)

# only keep adjusted data 
df = df[['Adj. Open',  'Adj. High',  'Adj. Low',  'Adj. Close', 'Adj. Volume']]
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Close'] * 100.0 # HL_PCT High low percentage
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0
df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]

df.fillna(value=-99999, inplace=True)

predict_lenght = int(math.ceil(0.1 * len(df))) # we are using 90% of the data to "train" our model and 10% to make predictions
predict_col = 'Adj. Close' # we want to predict the adj close price
df['label'] = df[predict_col].shift(-predict_lenght)
df
# Out:
#              Adj. Close    HL_PCT  PCT_change  Adj. Volume       label
# Date
# 2004-08-19    50.322842  8.072956    0.324968   44659000.0  214.005615
# 2004-08-20    54.322689  7.921706    7.227007   22834300.0  210.725489
# 2004-08-23    54.869377  4.049360   -1.227880   18256100.0  208.072299
# 2004-08-24    52.597363  7.657099   -5.726357   15247300.0  218.288837
# 2004-08-25    53.164113  3.886792    1.183658    9188600.0  223.309335
# ...                 ...       ...         ...          ...         ...
# 2018-03-21  1094.000000  1.964351    0.130884    1990515.0         NaN
# 2018-03-22  1053.150000  3.254997   -2.487014    3418154.0         NaN
# 2018-03-23  1026.550000  4.082607   -2.360729    2413517.0         NaN
# 2018-03-26  1054.090000  4.619150    0.332191    3272409.0         NaN
# 2018-03-27  1006.940000  6.645878   -5.353887    2940957.0         NaN
#
# [3424 rows x 5 columns]

# %%
# split and prepare data

# x = features
# y = labels

x = np.array(df.drop(['label'], axis=1)) # 1 denotes which axis
# mean value along the axis is subtracted from x and the resulting value 
# is divided by standard deviation along the axis.
# see https://scikit-learn.org/stable/modules/preprocessing.html
x = preprocessing.scale(x) 

x_predict = x[-predict_lenght:] # these are the last 10% of the data. We will use these to make predictions
# the predict data frame will hold our predicted values
predict_df = df.iloc[-predict_lenght:] # iloc: Purely integer-location based indexing for selection by position
predict_df = predict_df.rename(columns={"label":"Prediction"})

# getting our "training" data
x = x[:-predict_lenght]
df.dropna(inplace=True)
y = np.array(df["label"])

x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=0.2)

predict_df
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume  Prediction
# Date
# 2016-11-11      771.75  1.522514   -0.651382    3592641.0         NaN
# 2016-11-14      753.22  3.742598   -2.402301    3688274.0         NaN
# 2016-11-15      775.16  1.937355    1.265889    2943889.0         NaN
# 2016-11-16      779.98  2.201338   -0.237900    1798360.0         NaN
# 2016-11-17      786.16  1.151165    0.467732    1533679.0         NaN
# ...                ...       ...         ...          ...         ...
# 2018-03-21     1094.00  1.964351    0.130884    1990515.0         NaN
# 2018-03-22     1053.15  3.254997   -2.487014    3418154.0         NaN
# 2018-03-23     1026.55  4.082607   -2.360729    2413517.0         NaN
# 2018-03-26     1054.09  4.619150    0.332191    3272409.0         NaN
# 2018-03-27     1006.94  6.645878   -5.353887    2940957.0         NaN
#
# [343 rows x 5 columns]

# %%
# do linear regression

if os.path.exists('linearregression.pickle'):
    clf = pickle.load(open('linearregression.pickle','rb'))
else:
    clf = LinearRegression(n_jobs=-1) # do as many jobs as possible
    clf.fit(x_train, y_train) # fit/"train" to data
    with open('linearregression.pickle','wb') as f: # save classifier
        pickle.dump(clf, f)
    
accuracy = clf.score(x_test, y_test)
forecast = clf.predict(x_predict)

print(forecast,accuracy, predict_lenght)
print(f"accuracy: {accuracy}")
# Out:
# [ 965.333473    957.0318505   973.31051771  982.09745783  983.0460617
#   975.97538957  982.3544691   982.48493761  981.02358006  972.90899047
#   992.33164505  988.74940153  977.42697387  968.78040187  958.3509138
#   976.65992785  972.97337692  997.18921023  995.73353841 1013.72830305
#  1007.76854346 1020.96369703 1023.70237854 1020.53138473 1012.46314071
#  1017.89507546 1016.01925691 1016.29089767 1008.97433516 1007.72572115
#  1013.7588381  1007.33637609 1002.82916482  994.23631558 1014.06559866
#  1009.73323149 1015.25250847 1037.46441877 1033.32222743 1030.00979659
#  1036.43709114 1036.73470542 1035.0718207  1032.08637337 1033.466049
#  1030.33609064 1031.22712737 1059.99671021 1060.86158183 1071.74418726
#  1068.9655578  1065.49223337 1032.744863   1024.77444297 1020.01314387
#  1025.14495306 1022.79812524 1025.96767476 1035.46117896 1037.00095777
#  1034.34955381 1041.00737663 1045.26205107 1047.03818291 1043.1815692
#  1049.5244161  1055.83138672 1058.13474296 1061.91503872 1063.65125188
#  1056.02658879 1060.54909376 1053.98245873 1069.43415395 1060.42184247
#  1058.52775674 1057.57458013 1062.44514909 1063.78291105 1070.52661429
#  1073.72765975 1077.65978249 1080.27510694 1083.88897874 1083.47053876
#  1086.21789334 1080.77973968 1073.46633039 1060.8007098  1046.47619179
#  1047.14611981 1053.4834077  1053.20617195 1062.36813745 1058.33870105
#  1055.06176769 1071.27232521 1062.03622406 1062.83034409 1055.74854379
#  1051.74215729 1049.25901363 1050.34120531 1049.05793813 1047.28621735
#  1072.85013392 1064.69355247 1068.02498965 1072.13295851 1069.37683411
#  1100.65893374 1111.72064962 1108.84372314 1109.92883439 1153.24881206
#  1166.90142218 1170.47800073 1186.64233349 1191.79020999 1185.5368735
#  1198.12671313 1191.63800289 1189.26173479 1192.53944141 1188.86827343
#  1196.65711657 1200.48450368 1182.09765057 1187.64481445 1189.35217118
#  1201.54575647 1210.40972207 1217.12482166 1241.75068962 1237.61404697
#  1239.4633935  1235.84923174 1233.7069613  1241.36072554 1252.99796384
#  1245.05668995 1247.55234955 1251.08601312 1236.42074401 1211.69078333
#  1213.90968524 1214.20985704 1204.15615885 1195.56887162 1217.06576337
#  1210.46908172 1221.16832935 1216.55649938 1231.23856071 1221.54995253
#  1188.80375642 1209.50262614 1176.81704113 1163.11081286 1153.71966517
