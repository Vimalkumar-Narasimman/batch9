# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Email: n.vimalkumar@hotmail.com / vimalkumar.narasiman@gmail.com
#
# Phone & WhatsApp: 8754490973
#
# Linked In: https://www.linkedin.com/in/vimalkumar-narasimman/

# %% [markdown]
# 16+ years’ overall experience in crucial twin areas of technology and domain (business) with wide exposure to various facets.
#
# Over 10+ years of hands-on experience on handling different type of data and comprehensive knowledge on Data Engineering, Data Architecture, Data Analysis, Business Intelligence, Machine Learning statistic and predative modeling, Analytics Modeling (like Decision tree, Linear & Logical Regression), Deep Learning, Text Mining and Natural Language Processing (NLP) and Artificial Intelligence Algorithms development.
#
# Dynamic and accomplished professional of product development across engineering disciplines with industry leaders in CRM, Banking and Aerospace domains with expertise in architecting, designing, solutioning, analyzing and developing Data as a Service (DaaS).
#
# Efficient Leader, combining strong technical knowledge, communications, interpersonal and mentoring skills with analytical abilities to enhance organizational performance, customer experiences and resource management.

# %% [markdown]
# ![image.png](attachment:image.png)
