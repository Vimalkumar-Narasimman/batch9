# %% [markdown]
# ### Supermarket Sales Data Analysis using CSV and Class concepts
#
# 1. Read <code>supermarket_sales.csv</code> to calculate below:
#     1. Find a total number of invoice for each Branch
#     2. Find the lowest unit price from the 'Health and beauty' Product line
#     3. Find the total number of 'Female' customer we have on 'Member' and 'Normal' type
#
# 2. Add all the above the elements in JSON and write a JSON as 'Sales_result.json' file
# 3. Define 'Class' to store all Sales information and perform the above calculations
# 4. Add exception handlers (Try... Except) whereever required
# 5. Use this notebook to type all your codes
