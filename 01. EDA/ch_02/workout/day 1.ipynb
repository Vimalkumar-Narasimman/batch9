# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
df =  pd.read_csv('../data/tsunamis.csv')
df
# Out:
#     alert        type                                              title  \
# 0     NaN  earthquake  M 5.0 - 165km NNW of Flying Fish Cove, Christm...
# 1   green  earthquake            M 6.7 - 262km NW of Ozernovskiy, Russia
# 2   green  earthquake        M 5.6 - 128km SE of Kimbe, Papua New Guinea
# 3   green  earthquake         M 6.5 - 148km S of Severo-Kuril'sk, Russia
# 4   green  earthquake        M 6.2 - 94km SW of Kokopo, Papua New Guinea
# ..    ...         ...                                                ...
# 56    NaN  earthquake         M 5.4 - 228km S of Taron, Papua New Guinea
# 57    NaN  earthquake       M 5.1 - 278km SE of Pondaguitan, Philippines
# 58  green  earthquake               M 5.1 - 64km SSW of Kaktovik, Alaska
# 59    NaN  earthquake                M 5.2 - 126km N of Dili, East Timor
# 60    NaN  earthquake   M 5.1 - 34km NW of Finschhafen, Papua New Guinea
#
#                                               place magType  mag  \
# ...

# %%
df.head(3)
# Out:
#    alert        type                                              title  \
# 0    NaN  earthquake  M 5.0 - 165km NNW of Flying Fish Cove, Christm...
# 1  green  earthquake            M 6.7 - 262km NW of Ozernovskiy, Russia
# 2  green  earthquake        M 5.6 - 128km SE of Kimbe, Papua New Guinea
#
#                                              place magType  mag           time
# 0  165km NNW of Flying Fish Cove, Christmas Island     mww  5.0  1539459504090
# 1                  262km NW of Ozernovskiy, Russia     mww  6.7  1539429023560
# 2              128km SE of Kimbe, Papua New Guinea     mww  5.6  1539312723620

# %%
df.tail(3)
# Out:
#     alert        type                                             title  \
# 58  green  earthquake              M 5.1 - 64km SSW of Kaktovik, Alaska
# 59    NaN  earthquake               M 5.2 - 126km N of Dili, East Timor
# 60    NaN  earthquake  M 5.1 - 34km NW of Finschhafen, Papua New Guinea
#
#                                        place magType  mag           time
# 58              64km SSW of Kaktovik, Alaska      ml  5.1  1537274456960
# 59               126km N of Dili, East Timor      mb  5.2  1537262729590
# 60  34km NW of Finschhafen, Papua New Guinea      mb  5.1  1537236235470

# %%
df['alert'].unique()
# Out:
# array([nan, 'green', 'red'], dtype=object)

# %%
df['alert'].value_counts()
# Out:
# green    25
# red       1
# Name: alert, dtype: int64

# %%
greenDF = df[(df['alert'] == 'green') & (df['mag'] >= 6.0)]

greenDF
# Out:
#     alert        type                                        title  \
# 1   green  earthquake      M 6.7 - 262km NW of Ozernovskiy, Russia
# 3   green  earthquake   M 6.5 - 148km S of Severo-Kuril'sk, Russia
# 4   green  earthquake  M 6.2 - 94km SW of Kokopo, Papua New Guinea
# 7   green  earthquake   M 7.0 - 117km E of Kimbe, Papua New Guinea
# 8   green  earthquake   M 6.1 - 132km E of Kimbe, Papua New Guinea
# 24  green  earthquake    M 6.0 - 33km S of Nggongi Satu, Indonesia
# 30  green  earthquake       M 6.7 - 263km NNE of Ndoi Island, Fiji
# 50  green  earthquake          M 6.1 - 55km NNW of Palu, Indonesia
#
#                                   place magType  mag           time
# 1       262km NW of Ozernovskiy, Russia     mww  6.7  1539429023560
# 3    148km S of Severo-Kuril'sk, Russia     mww  6.5  1539213362130
# 4   94km SW of Kokopo, Papua New Guinea     mww  6.2  1539208835130
# 7    117km E of Kimbe, Papua New Guinea     mww  7.0  1539204500290
# ...

# %%
with sqlite3.connect('../data/quakes.db') as connection:
    greenDF.to_sql('greentsunamis', connection, index=False, if_exists='replace')

# %%
with sqlite3.connect('../data/quakes.db') as connection:
    tsunamis = pd.read_sql('SELECT * FROM greentsunamis', connection)

# %%
tsunamis
# Out:
#    alert        type                                        title  \
# 0  green  earthquake      M 6.7 - 262km NW of Ozernovskiy, Russia
# 1  green  earthquake   M 6.5 - 148km S of Severo-Kuril'sk, Russia
# 2  green  earthquake  M 6.2 - 94km SW of Kokopo, Papua New Guinea
# 3  green  earthquake   M 7.0 - 117km E of Kimbe, Papua New Guinea
# 4  green  earthquake   M 6.1 - 132km E of Kimbe, Papua New Guinea
# 5  green  earthquake    M 6.0 - 33km S of Nggongi Satu, Indonesia
# 6  green  earthquake       M 6.7 - 263km NNE of Ndoi Island, Fiji
# 7  green  earthquake          M 6.1 - 55km NNW of Palu, Indonesia
#
#                                  place magType  mag           time
# 0      262km NW of Ozernovskiy, Russia     mww  6.7  1539429023560
# 1   148km S of Severo-Kuril'sk, Russia     mww  6.5  1539213362130
# 2  94km SW of Kokopo, Papua New Guinea     mww  6.2  1539208835130
# 3   117km E of Kimbe, Papua New Guinea     mww  7.0  1539204500290
# ...
